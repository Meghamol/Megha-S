# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import plotly.express as px
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('MobileTrain.csv')
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (2000, 21)

# %%
data.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
data.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
data.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %% [markdown]
# # Exploratory Data Analysis on the Dataset

# %%
plt.figure()
sns.barplot(y="battery_power", x="price_range", data=data)
# Out:
# <Axes: xlabel='price_range', ylabel='battery_power'>

# %% [markdown]
# ### Countplot of each column from the dataset

# %%
for i in data:
    if (data[i].nunique())<=30:
        sns.countplot(x=data[i])
        plt.show()

# %% [markdown]
# ### Distplot on various columns of the dataset

# %%
plt.figure(figsize=(30,10))
plt.subplot(331)
sns.distplot(data["battery_power"])

plt.subplot(332)
sns.distplot(data["clock_speed"])

plt.subplot(333)
sns.distplot(data["int_memory"])

plt.subplot(334)
sns.distplot(data["mobile_wt"])

plt.subplot(335)
sns.distplot(data["px_height"])

plt.subplot(336)
sns.distplot(data["px_width"])

plt.subplot(337)
sns.distplot(data["ram"])

plt.subplot(338)
sns.distplot(data["talk_time"])

plt.subplot(339)
sns.distplot(data["m_dep"])

plt.show()

# %% [markdown]
# ### Pie charts on various columns of the dataset

# %%
data["isBluetooth"]=''
for i in range(len(data)):
    if data["blue"][i]==0:
        data["isBluetooth"][i]="No"
    else:
        data["isBluetooth"][i]="Yes"
px.pie(data_frame=data, names="isBluetooth", title="Percentage of devices having bluetooth", hole=0.3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b860bcfb-b42e-4c19-b8b6-b8bf8798fd7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b860bcfb-b42e-4c19-b8b6-b8bf8798fd7d")) {                    Plotly.newPlot(                        "b860bcfb-b42e-4c19-b8b6-b8bf8798fd7d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"isBluetooth=%{label}<extra></extra>","labels":["No","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","Yes","No","No","No","No","Yes","Yes","No","No","No","Yes","No","No","No","Yes","Yes","No","No","Yes","No","No","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","No","Yes","No","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","No","No","No","No","Yes","Yes","Yes","No","No","No","No","No","Yes","No","No","No","No","No","No","No","Yes","No","Yes","No","No","No","No","No","No","No","Yes","Yes","No","No","No","No","Yes","Yes","No","No","Yes","No","Yes","No","No","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","No","No","No","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","No","No","Yes","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","Yes","No","No","No","No","No","No","Yes","No","No","No","No","No","Yes","No","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","No","No","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","No","Yes","No","Yes","No","Yes","No","No","No","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","Yes","No","No","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","No","No","No","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","Yes","No","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","No","Yes","No","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","No","No","No","Yes","No" ...

# %%
data["isDualSIM"]=''
for i in range(len(data)):
    if data["dual_sim"][i]==0:
        data["isDualSIM"][i]="No"
    else:
        data["isDualSIM"][i]="Yes"
px.pie(data_frame=data, names="isDualSIM", title="Percentage of devices having Dual SIM", hole=0.3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="482adedc-5fc5-4408-ac7e-171a8e8a1a19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("482adedc-5fc5-4408-ac7e-171a8e8a1a19")) {                    Plotly.newPlot(                        "482adedc-5fc5-4408-ac7e-171a8e8a1a19",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"isDualSIM=%{label}<extra></extra>","labels":["No","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","No","No","No","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","No","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","No","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","No","Yes","No","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","No","Yes","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","No","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","Yes","No","No","No","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","No","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","No","No","No","Yes","No","No","Yes","No","No","Yes","No","No","No","No","No","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","No","No","No","No","No","No","Yes","No","No","Yes","No","No","No","Yes","Yes","No","No","No","No","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","No","Yes","No","No","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","No","No","No","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","Yes","No","Yes","No","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","No","No","No","Yes","Yes","No","No","No","No","Yes","Yes","No","Yes","Yes"," ...

# %%
data["is_4G"]=''
for i in range(len(data)):
    if data["four_g"][i]==0:
        data["is_4G"][i]="No"
    else:
        data["is_4G"][i]="Yes"
px.pie(data_frame=data, names="is_4G", title="Percentage of devices having 4G", hole=0.3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ab25729f-6b20-4628-9898-e341aff60185" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab25729f-6b20-4628-9898-e341aff60185")) {                    Plotly.newPlot(                        "ab25729f-6b20-4628-9898-e341aff60185",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"is_4G=%{label}<extra></extra>","labels":["No","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","Yes","No","No","Yes","No","Yes","Yes","No","No","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","No","Yes","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","No","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","No","No","No","No","No","No","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","No","No","Yes","No","Yes","No","Yes","No","No","Yes","No","Yes","No","No","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","No","No","Yes","No","Yes","No","Yes","No","No","No","No","No","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","Yes","Yes","No","Yes","Yes","No","Yes","No","No","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","No","Yes","No","Yes","Yes","No","No","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","No","No","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","No","No","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","No","No","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","No","No","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","No","No","No","Yes","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","No","No","No","No","Yes","No","No","No","No","No","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","No","Yes","No","No","No","No","Yes","Yes","No","Yes","No","No","Yes","Yes ...

# %%
data["isWiFi"]=''
for i in range(len(data)):
    if data["wifi"][i]==0:
        data["isWiFi"][i]="No"
    else:
        data["isWiFi"][i]="Yes"
px.pie(data_frame=data, names="isWiFi", title="Percentage of devices having Dual SIM", hole=0.3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ec158408-2b90-47d9-b1b4-fadbc4b304bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec158408-2b90-47d9-b1b4-fadbc4b304bc")) {                    Plotly.newPlot(                        "ec158408-2b90-47d9-b1b4-fadbc4b304bc",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"isWiFi=%{label}<extra></extra>","labels":["Yes","No","No","No","No","No","Yes","Yes","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","No","No","No","No","Yes","No","Yes","Yes","No","Yes","No","No","Yes","No","No","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","Yes","No","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","Yes","No","No","No","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","Yes","No","No","Yes","Yes","No","No","Yes","No","No","Yes","No","No","No","No","Yes","No","Yes","No","No","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","Yes","Yes","No","Yes","No","Yes","No","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","No","No","Yes","No","Yes","No","No","Yes","No","Yes","No","No","No","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","No","No","Yes","No","No","No","No","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","No","No","No","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","No","No","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","No","No","No","No","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","No","No","No","Yes","Yes","No","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","No","No","Yes","Yes","No","No","No"," ...

# %%
data["Cores"]=''
for i in range(len(data)):
    if data["n_cores"][i]==1:
        data["Cores"][i]="Single Core"
    elif data["n_cores"][i]==2:
        data["Cores"][i]="Dual Core"
    elif data["n_cores"][i]==3:
        data["Cores"][i]="Triple Core"
    elif data["n_cores"][i]==4:
        data["Cores"][i]="Quad Core"
    elif data["n_cores"][i]==5:
        data["Cores"][i]="Penta Core"
    elif data["n_cores"][i]==6:
        data["Cores"][i]="Hexa Core"
    elif data["n_cores"][i]==7:
        data["Cores"][i]="Hepta Core"
    else:
      data["Cores"][i]="Octa Core"
px.pie(data_frame=data, names="Cores", title="Percentage of devices having Dual SIM", hole=0.3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="12d1d49f-cc71-4007-874f-2650d74640f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12d1d49f-cc71-4007-874f-2650d74640f3")) {                    Plotly.newPlot(                        "12d1d49f-cc71-4007-874f-2650d74640f3",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Cores=%{label}<extra></extra>","labels":["Dual Core","Triple Core","Penta Core","Hexa Core","Dual Core","Single Core","Octa Core","Quad Core","Hepta Core","Penta Core","Penta Core","Octa Core","Quad Core","Quad Core","Single Core","Dual Core","Octa Core","Triple Core","Penta Core","Quad Core","Hepta Core","Dual Core","Quad Core","Triple Core","Triple Core","Octa Core","Quad Core","Hepta Core","Dual Core","Penta Core","Hepta Core","Octa Core","Single Core","Quad Core","Octa Core","Octa Core","Quad Core","Dual Core","Hexa Core","Dual Core","Single Core","Dual Core","Dual Core","Triple Core","Dual Core","Triple Core","Octa Core","Hepta Core","Octa Core","Octa Core","Triple Core","Octa Core","Dual Core","Triple Core","Hepta Core","Triple Core","Octa Core","Triple Core","Hexa Core","Penta Core","Triple Core","Octa Core","Dual Core","Dual Core","Triple Core","Triple Core","Quad Core","Triple Core","Dual Core","Quad Core","Hepta Core","Quad Core","Triple Core","Single Core","Quad Core","Hexa Core","Triple Core","Single Core","Quad Core","Hexa Core","Hepta Core","Quad Core","Penta Core","Triple Core","Single Core","Octa Core","Penta Core","Triple Core","Penta Core","Quad Core","Triple Core","Hepta Core","Hepta Core","Hexa Core","Triple Core","Triple Core","Penta Core","Hexa Core","Dual Core","Hepta Core","Hexa Core","Octa Core","Penta Core","Quad Core","Hepta Core","Quad Core","Penta Core","Penta Core","Single Core","Single Core","Triple Core","Hepta Core","Hexa Core","Penta Core","Hepta Core","Hepta Core","Octa Core","Triple Core","Single Core","Triple Core","Octa Core","Quad Core","Triple Core","Dual Core","Penta Core","Single Core","Quad Core","Hexa Core","Triple Core","Hexa Core","Hepta Core","Single Core","Hepta Core","Octa Core","Quad Core","Penta Core","Hexa Core","Octa Core","Hepta Core","Octa Core","Single Core","Triple Core","Single Core","Hepta Core","Triple Core","Dual Core","Dual Core","Hepta Core","Triple Core","Single Core","Penta Core","Hepta Core","Hexa Core","Dual Core","Dual Core","Single Core","Quad Core","Hexa Core","Hexa Core","Single Core","Penta Core","Hexa Core","Penta Core","Single Core","Octa Core","Quad Core","Octa Core","Hexa Core","Hepta Core","Quad Core","Hepta Core","Penta Core","Quad Core","Penta Core","Penta Core","Hexa Core","Hepta Core","Penta Core","Dual Core","Hepta Core","Single Core","Hexa Core","Octa Core","Quad Core","Penta Core","Triple Core","Hexa Core","Single Core","Single Core","Penta Core","Single Core","Penta Core","Octa Core","Dual Core","Quad Core","Hepta Core","Triple Core","Triple Core","Quad Core","Triple Core","Single Core","Hepta Core","Triple Core","Hepta Core","Hexa Core","Octa Core","Hexa Core","Penta Core","Hepta Core","Hexa Core","Triple Core","Octa Core","Penta Core","Penta Core","Single Core","Triple Core","Octa Core","Penta Core","Triple Core","Penta Core","Penta Core","Dual Core","Quad Core","Hexa Core","Quad Core","Dual Core","Single Core","Octa Core","Quad Core","Triple Core","Penta Core","Single Core","Octa Core","Triple Core","Dual Core","Single Core","Penta Core","Penta Core","Hepta Core","Quad Core","Octa Core","Hepta Core","Hexa Core","Penta Core","Hepta Core","Hepta Core","Dual Core","Quad Core","Penta Core","Dual Core","Dual Core","Penta Core","Octa Core","Quad Core","Single Core","Hepta Core","Quad Core","Hepta Core","Triple Core","Hexa Core","Hepta Core"," ...

# %% [markdown]
# ### Histogram using plotly.express library on various columns

# %%
px.histogram(data_frame=data, x="isBluetooth", color="price_range", title="Comparison according to price range of bluetooth devices or not")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ff86c498-bb77-4023-abf8-84ed76b5f8a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff86c498-bb77-4023-abf8-84ed76b5f8a8")) {                    Plotly.newPlot(                        "ff86c498-bb77-4023-abf8-84ed76b5f8a8",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price_range=1<br>isBluetooth=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"x":["No","Yes","No","No","Yes","Yes","No","No","Yes","No","Yes","Yes","No","No","Yes","No","No","No","No","No","No","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","No","No","No","No","Yes","No","Yes","Yes","No","No","Yes","No","No","Yes","Yes","No","No","No","Yes","No","No","No","No","No","No","No","Yes","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","No","No","No","Yes","No","Yes","Yes","No","No","No","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","No","Yes","No","Yes","No","No","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","No","No","Yes","Yes","No","No","No","No","No","Yes","No","Yes","Yes","No","Yes","Yes","No","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","No","No","No","No","No","No","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","No","No","No","Yes","No","Yes","No","No","Yes","No","No","Yes","No","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","No","No","No","Yes","Yes","No","Yes","Yes","No","Yes","No","No","No","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","No","No","No","No","No","No","No","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","Yes","No","No","No","Yes","Yes","No","No","No","No","No","No","No","Yes","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","No","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","Yes","Yes","No","Yes","No","No","Yes","Yes","No"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price_range=2<br>isBluetooth=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"x":["Yes","Yes","Yes","Yes","Yes","No","No","No","No","Yes","No","Yes","No","No","No","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","N ...

# %%
px.histogram(data_frame=data, x="isDualSIM", color="price_range", title="Comparison according to price range of Dual SIM devices or not")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="38243439-889c-424f-a542-169f51f23fee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38243439-889c-424f-a542-169f51f23fee")) {                    Plotly.newPlot(                        "38243439-889c-424f-a542-169f51f23fee",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price_range=1<br>isDualSIM=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"x":["No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","No","No","Yes","Yes","No","Yes","No","Yes","No","No","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","No","No","No","Yes","Yes","No","No","No","Yes","No","No","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","Yes","No","No","No","Yes","No","Yes","No","No","Yes","No","Yes","No","No","No","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","No","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","Yes","No","No","Yes","No","No","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","No","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","Yes","Yes","No","No","No","No","No","No","Yes","Yes","Yes","Yes","No","No","Yes","No","No","No","No","No","No","No","Yes","No","Yes","No","Yes","No","Yes","No","No","Yes","Yes","Yes","No","No","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","No","Yes","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","Yes","Yes","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","No","No","No","No","Yes","Yes","No","Yes","No","No","Yes","Yes","No","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","Yes","No","No","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","Yes","No","Yes","No","No","No","Yes","No","No","Yes","Yes","No","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","No","Yes","Yes","No","No"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price_range=2<br>isDualSIM=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"x":["Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","N ...

# %%
px.histogram(data_frame=data, x="is_4G", color="price_range", title="Comparison according to price range of 4G devices or not")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7cc55363-0ef9-4478-9bf4-a3e84446f5fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cc55363-0ef9-4478-9bf4-a3e84446f5fe")) {                    Plotly.newPlot(                        "7cc55363-0ef9-4478-9bf4-a3e84446f5fe",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price_range=1<br>is_4G=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"x":["No","Yes","No","No","No","No","No","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","No","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","No","Yes","No","No","No","No","Yes","Yes","No","No","Yes","No","Yes","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","No","Yes","No","Yes","No","No","No","No","Yes","Yes","No","No","Yes","Yes","No","No","Yes","No","No","No","No","Yes","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","No","No","No","Yes","Yes","No","No","Yes","Yes","Yes","Yes","No","No","No","No","No","No","Yes","No","No","Yes","No","No","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","No","No","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","Yes","Yes","No","Yes","Yes","No","Yes","No","Yes","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","Yes","No","No","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","No","No","No","Yes","Yes","Yes","Yes","Yes","No","No","Yes","No","No"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price_range=2<br>is_4G=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"x":["Yes","Yes","No","No","Yes","Yes","Yes","No","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","No"," ...

# %%
px.histogram(data_frame=data, x="Cores", color="price_range", title="Comparison according to price range of number of cores per device")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ac6c597e-d22c-4984-b42e-873282fc4be8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac6c597e-d22c-4984-b42e-873282fc4be8")) {                    Plotly.newPlot(                        "ac6c597e-d22c-4984-b42e-873282fc4be8",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price_range=1<br>Cores=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"x":["Dual Core","Dual Core","Single Core","Quad Core","Penta Core","Quad Core","Quad Core","Triple Core","Single Core","Octa Core","Quad Core","Dual Core","Triple Core","Triple Core","Hepta Core","Triple Core","Hexa Core","Triple Core","Hexa Core","Hexa Core","Triple Core","Single Core","Octa Core","Triple Core","Hepta Core","Octa Core","Penta Core","Quad Core","Triple Core","Hepta Core","Triple Core","Triple Core","Hexa Core","Single Core","Octa Core","Hexa Core","Dual Core","Penta Core","Hexa Core","Single Core","Single Core","Octa Core","Quad Core","Penta Core","Hepta Core","Single Core","Single Core","Quad Core","Triple Core","Hepta Core","Penta Core","Penta Core","Triple Core","Triple Core","Penta Core","Hepta Core","Quad Core","Penta Core","Octa Core","Hepta Core","Hepta Core","Quad Core","Dual Core","Hexa Core","Single Core","Triple Core","Quad Core","Hepta Core","Triple Core","Single Core","Single Core","Hexa Core","Hepta Core","Hexa Core","Hepta Core","Triple Core","Triple Core","Quad Core","Triple Core","Single Core","Penta Core","Single Core","Hexa Core","Quad Core","Triple Core","Hexa Core","Quad Core","Single Core","Quad Core","Hepta Core","Hexa Core","Hepta Core","Hexa Core","Hepta Core","Octa Core","Hepta Core","Quad Core","Quad Core","Penta Core","Octa Core","Penta Core","Hepta Core","Penta Core","Hexa Core","Dual Core","Octa Core","Hexa Core","Hexa Core","Hepta Core","Triple Core","Octa Core","Dual Core","Triple Core","Triple Core","Penta Core","Octa Core","Single Core","Triple Core","Hexa Core","Penta Core","Penta Core","Dual Core","Hepta Core","Single Core","Quad Core","Hexa Core","Octa Core","Octa Core","Quad Core","Octa Core","Octa Core","Penta Core","Dual Core","Hexa Core","Octa Core","Dual Core","Octa Core","Octa Core","Dual Core","Hexa Core","Dual Core","Quad Core","Penta Core","Hexa Core","Hepta Core","Dual Core","Dual Core","Single Core","Hexa Core","Quad Core","Quad Core","Triple Core","Octa Core","Octa Core","Triple Core","Triple Core","Penta Core","Octa Core","Single Core","Single Core","Hepta Core","Quad Core","Triple Core","Quad Core","Hepta Core","Single Core","Triple Core","Hexa Core","Octa Core","Single Core","Triple Core","Octa Core","Triple Core","Triple Core","Hepta Core","Hepta Core","Triple Core","Hexa Core","Triple Core","Hepta Core","Single Core","Dual Core","Dual Core","Hexa Core","Single Core","Dual Core","Dual Core","Dual Core","Hepta Core","Single Core","Hexa Core","Single Core","Hepta Core","Octa Core","Single Core","Triple Core","Triple Core","Dual Core","Octa Core","Octa Core","Triple Core","Dual Core","Single Core","Penta Core","Single Core","Dual Core","Triple Core","Quad Core","Dual Core","Quad Core","Single Core","Triple Core","Penta Core","Single Core","Quad Core","Triple Core","Quad Core","Quad Core","Dual Core","Hexa Core","Octa Core","Single Core","Single Core","Hepta Core","Single Core","Triple Core","Octa Core","Single Core","Penta Core","Hepta Core","Penta Core","Hepta Core","Hepta Core","Quad Core","Dual Core","Penta Core","Quad Core","Triple Core","Dual Core","Dual Core","Hepta Core","Triple Core","Penta Core","Hepta Core","Single Core","Single Core","Triple Core","Penta Core","Penta ...

# %%
px.histogram(data_frame=data, x="isWiFi", color="price_range", title="Comparison according to price range of WiFi devices or not")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="82862c66-fe70-4cda-918e-2c0f691dfba2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82862c66-fe70-4cda-918e-2c0f691dfba2")) {                    Plotly.newPlot(                        "82862c66-fe70-4cda-918e-2c0f691dfba2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price_range=1<br>isWiFi=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"x":["Yes","No","No","No","No","Yes","Yes","No","Yes","No","Yes","No","No","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","No","No","No","No","No","No","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","No","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","Yes","No","Yes","No","No","No","Yes","No","Yes","Yes","No","No","Yes","No","No","No","Yes","No","Yes","Yes","No","No","Yes","No","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","No","Yes","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","No","No","No","Yes","Yes","No","Yes","No","No","No","No","No","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","No","Yes","No","Yes","No","No","No","Yes","Yes","No","No","Yes","No","No","Yes","Yes","No","No","No","No","No","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","Yes","No","No","No","No","No","No","Yes","Yes","No","No","No","No","No","Yes","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","No","No","Yes","Yes","No","No","No","Yes","Yes","Yes","No","No","Yes","Yes","No","No","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","No","No","Yes","No","No","No","Yes","No","No","Yes","No","Yes","Yes","No","No","No","Yes","No","No","Yes","Yes","No","Yes","Yes","No","No","No","No","No","No","Yes","No","Yes","Yes","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","Yes","No","No","No","Yes","Yes","No","No","Yes","No"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price_range=2<br>isWiFi=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"x":["No","No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","No","No","No","Yes","Yes","No","Yes","No","Yes","Yes","No","No","No","No","No","No","Y ...

# %%
data_f = data[data['sc_w'] != 0]
data_f.shape
# Out:
# (1820, 26)

# %%
sns.set()
price_plot=data_f['price_range'].value_counts().plot(kind='bar')
plt.xlabel('price_range')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Data Distribution

# %%
sns.set(rc={'figure.figsize':(5,5)})
ax=sns.displot(data=data_f["battery_power"])
plt.show()

# %%
sns.set(rc={'figure.figsize':(5,5)})
ax=sns.displot(data=data_f["blue"])
plt.show()

# %%
sns.set(rc={'figure.figsize':(5,5)})
ax=sns.displot(data=data_f["m_dep"])
plt.show()

# %% [markdown]
# ### missing values or missing data.

# %%
X=data_f.drop(['price_range'], axis=1)
y=data_f['price_range']
#missing values
X.isna().any()
# Out:
# battery_power    False
# blue             False
# clock_speed      False
# dual_sim         False
# fc               False
# four_g           False
# int_memory       False
# m_dep            False
# mobile_wt        False
# n_cores          False
# pc               False
# px_height        False
# px_width         False
# ram              False
# sc_h             False
# sc_w             False
# talk_time        False
# three_g          False
# touch_screen     False
# wifi             False
# isBluetooth      False
# isDualSIM        False
# is_4G            False
# isWiFi           False
# Cores            False
# dtype: bool

# %%
freqgraph = data.select_dtypes(include=['float'])
freqgraph.hist(figsize=(20,10))
plt.show()

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,annot=True,vmax=0.7,vmin=0.7,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
cat_cols = data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['isBluetooth', 'isDualSIM', 'is_4G', 'isWiFi', 'Cores'], dtype='object')
# Numerical Variables:
# ['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g', 'touch_screen', 'wifi', 'price_range']

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(data[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# battery_power
# Skew : 0.03
# blue
# Skew : 0.02
# clock_speed
# Skew : 0.18
# dual_sim
# Skew : -0.04
# fc
# Skew : 1.02
# four_g
# Skew : -0.09
# int_memory
# Skew : 0.06
# m_dep
# Skew : 0.09
# mobile_wt
# Skew : 0.01
# n_cores
# Skew : 0.0
# pc
# Skew : 0.02
# px_height
# Skew : 0.67
# px_width
# Skew : 0.01
# ram
# Skew : 0.01
# sc_h
# Skew : -0.1
# sc_w
# Skew : 0.63
# talk_time
# Skew : 0.01
# three_g
# Skew : -1.23
# touch_screen
# Skew : -0.01
# wifi
# Skew : -0.03
# price_range
# Skew : 0.0

# %%
data1 = data.loc[:,['battery_power','blue','dual_sim','fc','four_g','int_memory','m_dep','mobile_wt','n_cores','pc','px_height','px_width','ram','sc_h','sc_w','price_range']]
data1
# Out:
#       battery_power  blue  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  \
# 0               842     0         0   1       0           7    0.6        188
# 1              1021     1         1   0       1          53    0.7        136
# 2               563     1         1   2       1          41    0.9        145
# 3               615     1         0   0       0          10    0.8        131
# 4              1821     1         0  13       1          44    0.6        141
# ...             ...   ...       ...  ..     ...         ...    ...        ...
# 1995            794     1         1   0       1           2    0.8        106
# 1996           1965     1         1   0       0          39    0.2        187
# 1997           1911     0         1   1       1          36    0.7        108
# 1998           1512     0         0   4       1          46    0.1        145
# 1999            510     1         1   5       1          45    0.9        168
#
#       n_cores  pc  px_height  px_width   ram  sc_h  sc_w  price_range
# 0           2   2         20       756  2549     9     7            1
# 1           3   6        905      1988  2631    17     3            2
# 2           5   6       1263      1716  2603    11     2            2
# 3           6   9       1216      1786  2769    16     8            2
# 4           2  14       1208      1212  1411     8     2            1
# ...       ...  ..        ...       ...   ...   ...   ...          ...
# 1995        6  14       1222      1890   668    13     4            0
# 1996        4   3        915      1965  2032    11    10            2
# 1997        8   3        868      1632  3057     9     1            3
# 1998        5   5        336       670   869    18    10            0
# 1999        6  16        483       754  3919    19     4            3
#
# [2000 rows x 16 columns]

# %%
data2 = data.loc[:,['talk_time','three_g','wifi','touch_screen','clock_speed']]
data2
# Out:
#       talk_time  three_g  wifi  touch_screen  clock_speed
# 0            19        0     1             0          2.2
# 1             7        1     0             1          0.5
# 2             9        1     0             1          0.5
# 3            11        1     0             0          2.5
# 4            15        1     0             1          1.2
# ...         ...      ...   ...           ...          ...
# 1995         19        1     0             1          0.5
# 1996         16        1     1             1          2.6
# 1997          5        1     0             1          0.9
# 1998         19        1     1             1          0.9
# 1999          2        1     1             1          2.0
#
# [2000 rows x 5 columns]

# %% [markdown]
# Merging Datasets

# %%
data3 = pd.concat([data1, data2], axis=1)
data3
# Out:
#       battery_power  blue  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  \
# 0               842     0         0   1       0           7    0.6        188
# 1              1021     1         1   0       1          53    0.7        136
# 2               563     1         1   2       1          41    0.9        145
# 3               615     1         0   0       0          10    0.8        131
# 4              1821     1         0  13       1          44    0.6        141
# ...             ...   ...       ...  ..     ...         ...    ...        ...
# 1995            794     1         1   0       1           2    0.8        106
# 1996           1965     1         1   0       0          39    0.2        187
# 1997           1911     0         1   1       1          36    0.7        108
# 1998           1512     0         0   4       1          46    0.1        145
# 1999            510     1         1   5       1          45    0.9        168
#
#       n_cores  pc  ...  px_width   ram  sc_h  sc_w  price_range  talk_time  \
# 0           2   2  ...       756  2549     9     7            1         19
# 1           3   6  ...      1988  2631    17     3            2          7
# 2           5   6  ...      1716  2603    11     2            2          9
# 3           6   9  ...      1786  2769    16     8            2         11
# 4           2  14  ...      1212  1411     8     2            1         15
# ...       ...  ..  ...       ...   ...   ...   ...          ...        ...
# 1995        6  14  ...      1890   668    13     4            0         19
# 1996        4   3  ...      1965  2032    11    10            2         16
# 1997        8   3  ...      1632  3057     9     1            3          5
# 1998        5   5  ...       670   869    18    10            0         19
# 1999        6  16  ...       754  3919    19     4            3          2
#
#       three_g  wifi  touch_screen  clock_speed
# 0           0     1             0          2.2
# 1           1     0             1          0.5
# 2           1     0             1          0.5
# 3           1     0             0          2.5
# 4           1     0             1          1.2
# ...       ...   ...           ...          ...
# 1995        1     0             1          0.5
# 1996        1     1             1          2.6
# 1997        1     0             1          0.9
# 1998        1     1             1          0.9
# 1999        1     1             1          2.0
#
# [2000 rows x 21 columns]

# %% [markdown]
# Ranking dataset according to price range

# %%
dt = data
dt["rank_by_price"] = dt["price_range"].rank()
dt1 = dt
dt1.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  three_g  touch_screen  wifi  price_range  \
# 0        188        2  ...        0             0     1            1
# 1        136        3  ...        1             1     0            2
# 2        145        5  ...        1             1     0            2
# 3        131        6  ...        1             0     0            2
# 4        141        2  ...        1             1     0            1
#
#    isBluetooth  isDualSIM  is_4G  isWiFi        Cores  rank_by_price
# 0           No         No     No     Yes    Dual Core          750.5
# 1          Yes        Yes    Yes      No  Triple Core         1250.5
# 2          Yes        Yes    Yes      No   Penta Core         1250.5
# 3          Yes         No     No      No    Hexa Core         1250.5
# 4          Yes         No    Yes      No    Dual Core          750.5
#
# [5 rows x 27 columns]

# %% [markdown]
# Sorting above dataset according to ranked_price_range

# %%
dt1.sort_values(by=["rank_by_price"])
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1838            720     1          0.9         1  12       1          14
# 1762            808     1          0.5         1   3       0          46
# 419             914     1          0.9         0   2       0           4
# 846            1489     0          2.4         1   8       0          32
# 845            1907     0          2.0         0  13       0          55
# ...             ...   ...          ...       ...  ..     ...         ...
# 981            1046     1          2.8         1   0       1          58
# 982            1035     0          0.6         1   2       1          44
# 987            1688     0          2.5         0   0       1          21
# 956             862     0          2.3         0   9       1           6
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  three_g  touch_screen  wifi  \
# 1838    0.8        165        4  ...        1             1     0
# 1762    0.5        105        8  ...        1             0     1
# 419     0.8        100        2  ...        1             1     0
# 846     0.6        200        1  ...        0             0     0
# 845     0.9        105        7  ...        1             0     1
# ...     ...        ...      ...  ...      ...           ...   ...
# 981     0.2        100        8  ...        1             1     1
# 982     0.5         99        3  ...        1             1     0
# 987     0.2        170        7  ...        1             1     1
# 956     0.1        107        8  ...        1             1     1
# 1999    0.9        168        6  ...        1             1     1
#
#       price_range  isBluetooth  isDualSIM  is_4G  isWiFi        Cores  \
# 1838            0          Yes        Yes    Yes      No    Quad Core
# 1762            0          Yes        Yes     No     Yes    Octa Core
# 419             0          Yes         No     No      No    Dual Core
# 846             0           No        Yes     No      No  Single Core
# 845             0           No         No     No     Yes   Hepta Core
# ...           ...          ...        ...    ...     ...          ...
# 981             3          Yes        Yes    Yes     Yes    Octa Core
# 982             3           No        Yes    Yes      No  Triple Core
# 987             3           No         No    Yes     Yes   Hepta Core
# 956             3           No         No    Yes     Yes    Octa Core
# 1999            3          Yes        Yes    Yes     Yes    Hexa Core
#
#       rank_by_price
# 1838          250.5
# 1762          250.5
# 419           250.5
# 846           250.5
# 845           250.5
# ...             ...
# 981          1750.5
# 982          1750.5
# 987          1750.5
# 956          1750.5
# 1999         1750.5
#
# [2000 rows x 27 columns]

# %% [markdown]
# Ranking on all the features using rank()

# %%
dt2 = data
RankedDataset1 = dt2.rank()
RankedDataset1.sort_values(by="price_range")
# Out:
#       battery_power    blue  clock_speed  dual_sim      fc  four_g  \
# 1838          320.5  1505.5        638.5    1491.0  1853.0  1479.0
# 1762          435.5  1505.5        207.0    1491.0   993.5   479.0
# 419           589.0  1505.5        638.5     491.0   814.0   479.0
# 846          1323.5   505.5       1612.5    1491.0  1601.0   479.0
# 845          1875.0   505.5       1337.0     491.0  1895.5   479.0
# ...             ...     ...          ...       ...     ...     ...
# 981           753.0  1505.5       1868.0    1491.0   237.5  1479.0
# 982           737.5   505.5        450.5    1491.0   814.0  1479.0
# 987          1583.0   505.5       1678.5     491.0   237.5  1479.0
# 956           515.5   505.5       1544.5     491.0  1678.5  1479.0
# 1999           21.0  1505.5       1337.0    1491.0  1281.0  1479.0
#
#       int_memory   m_dep  mobile_wt  n_cores  ...  three_g  touch_screen  \
# 1838       432.0  1595.5     1414.5    872.5  ...   1239.0        1497.5
# 1762      1451.5  1003.0      436.0   1872.5  ...   1239.0         497.5
# 419         77.5  1595.5      325.5    366.0  ...   1239.0        1497.5
# 846       1011.0  1198.5     1991.0    121.5  ...    239.0         497.5
# 845       1727.0  1797.0      436.0   1615.0  ...   1239.0         497.5
# ...          ...     ...        ...      ...  ...      ...           ...
# 981       1828.5   427.0      325.5   1872.5  ...   1239.0        1497.5
# 982       1382.0  1003.0      309.0    612.5  ...   1239.0        1497.5
# 987        669.5   427.0     1496.0   1615.0  ...   1239.0        1497.5
# 956        142.0   160.5      472.5   1872.5  ...   1239.0        1497.5
# 1999      1418.0  1797.0     1457.5   1370.5  ...   1239.0        1497.5
#
#         wifi  price_range  isBluetooth  isDualSIM   is_4G  isWiFi   Cores  \
# 1838   493.5        250.5       1505.5     1491.0  1479.0   493.5  1375.5
# 1762  1493.5        250.5       1505.5     1491.0   479.0  1493.5   864.5
# 419    493.5        250.5       1505.5      491.0   479.0   493.5   124.0
# 846    493.5        250.5        505.5     1491.0   479.0   493.5  1633.5
# 845   1493.5        250.5        505.5      491.0   479.0  1493.5   377.0
# ...      ...          ...          ...        ...     ...     ...     ...
# 981   1493.5       1750.5       1505.5     1491.0  1479.0  1493.5   864.5
# 982    493.5       1750.5        505.5     1491.0  1479.0   493.5  1877.5
# 987   1493.5       1750.5        505.5      491.0  1479.0  1493.5   377.0
# 956   1493.5       1750.5        505.5      491.0  1479.0  1493.5   864.5
# 1999  1493.5       1750.5       1505.5     1491.0  1479.0  1493.5   621.5
#
#       rank_by_price
# 1838          250.5
# 1762          250.5
# 419           250.5
# 846           250.5
# 845           250.5
# ...             ...
# 981          1750.5
# 982          1750.5
# 987          1750.5
# 956          1750.5
# 1999         1750.5
#
# [2000 rows x 27 columns]

# %% [markdown]
# Ranking all the features separately to correct output

# %%
b = dt2
b["rank_by_price"] = b["price_range"].rank()
b["rank_by_battery"] = b["battery_power"].rank(ascending=False)
b["rank_by_blueooth"] = b["blue"].rank(ascending=False)
b["rank_by_clockspeed"] = b["clock_speed"].rank(ascending=False)
b["rank_by_DualSIM"] = b["dual_sim"].rank(ascending=False)
b["rank_by_fc"] = b["fc"].rank(ascending=False)
b["rank_by_4G"] = b["four_g"].rank(ascending=False)
b["rank_by_InternalMemory"] = b["int_memory"].rank(ascending=False)
b["rank_by_mdep"] = b["m_dep"].rank(ascending=False)
b["rank_by_weight"] = b["mobile_wt"].rank(ascending=True)
b["rank_by_ncores"] = b["n_cores"].rank(ascending=False)
b["rank_by_pc"] = b["pc"].rank(ascending=False)
b["rank_by_height"] = b["px_height"].rank(ascending=False)
b["rank_by_width"] = b["px_width"].rank(ascending=False)
b["rank_by_ram"] = b["ram"].rank(ascending=False)
b["rank_by_sch"] = b["sc_h"].rank(ascending=False)
b["rank_by_scw"] = b["sc_w"].rank(ascending=False)
b["rank_by_talktime"] = b["talk_time"].rank(ascending=False)
b["rank_by_3G"] = b["three_g"].rank(ascending=False)
b["rank_by_touchscreen"] = b["touch_screen"].rank(ascending=False)
b["rank_by_wifi"] = b["wifi"].rank(ascending=False)
b.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  rank_by_pc  rank_by_height  rank_by_width  \
# 0        188        2  ...      1746.0          1972.5         1664.5
# 1        136        3  ...      1402.0           545.5           17.0
# 2        145        5  ...      1402.0           212.0          386.5
# 3        131        6  ...      1090.5           250.0          287.0
# 4        141        2  ...       606.5           261.5         1054.0
#
#    rank_by_ram  rank_by_sch  rank_by_scw  rank_by_talktime  rank_by_3G  \
# 0        762.5       1459.5        716.5             159.0      1762.0
# 1        714.0        341.0       1355.0            1418.5       762.0
# 2        732.0       1209.5       1532.5            1202.5       762.0
# 3        639.0        509.0        588.0             996.0       762.0
# 4       1375.0       1580.0       1532.5             587.0       762.0
#
#    rank_by_touchscreen  rank_by_wifi
# 0               1503.5         507.5
# 1                503.5        1507.5
# 2                503.5        1507.5
# 3               1503.5        1507.5
# 4                503.5        1507.5
#
# [5 rows x 47 columns]

# %%
RankedDataset2 = b.iloc[:,21:]
RankedDataset2
# Out:
#      isBluetooth isDualSIM is_4G isWiFi        Cores  rank_by_price  \
# 0             No        No    No    Yes    Dual Core          750.5
# 1            Yes       Yes   Yes     No  Triple Core         1250.5
# 2            Yes       Yes   Yes     No   Penta Core         1250.5
# 3            Yes        No    No     No    Hexa Core         1250.5
# 4            Yes        No   Yes     No    Dual Core          750.5
# ...          ...       ...   ...    ...          ...            ...
# 1995         Yes       Yes   Yes     No    Hexa Core          250.5
# 1996         Yes       Yes    No    Yes    Quad Core         1250.5
# 1997          No       Yes   Yes     No    Octa Core         1750.5
# 1998          No        No   Yes    Yes   Penta Core          250.5
# 1999         Yes       Yes   Yes    Yes    Hexa Core         1750.5
#
#       rank_by_battery  rank_by_blueooth  rank_by_clockspeed  rank_by_DualSIM  \
# 0              1512.5            1495.5               525.0           1510.0
# 1              1278.5             495.5              1794.0            510.0
# 2              1909.5             495.5              1794.0            510.0
# 3              1830.0             495.5               322.5           1510.0
# 4               242.0             495.5              1193.5           1510.0
# ...               ...               ...                 ...              ...
# 1995           1587.5             495.5              1794.0            510.0
# 1996             58.0             495.5               258.0            510.0
# 1997            121.5            1495.5              1362.5            510.0
# 1998            648.0            1495.5              1362.5           1510.0
# 1999           1980.0             495.5               664.0            510.0
#
#       ...  rank_by_pc  rank_by_height  rank_by_width  rank_by_ram  \
# 0     ...      1746.0          1972.5         1664.5        762.5
# 1     ...      1402.0           545.5           17.0        714.0
# 2     ...      1402.0           212.0          386.5        732.0
# 3     ...      1090.5           250.0          287.0        639.0
# 4     ...       606.5           261.5         1054.0       1375.0
# ...   ...         ...             ...            ...          ...
# 1995  ...       606.5           244.5          163.0       1767.0
# 1996  ...      1650.0           536.0           54.5       1062.0
# 1997  ...      1650.0           583.5          502.0        504.0
# 1998  ...      1479.0          1395.5         1792.5       1664.5
# 1999  ...       418.5          1133.0         1669.5         42.0
#
#       rank_by_sch  rank_by_scw  rank_by_talktime  rank_by_3G  \
# 0          1459.5        716.5             159.0      1762.0
# 1           341.0       1355.0            1418.5       762.0
# 2          1209.5       1532.5            1202.5       762.0
# 3           509.0        588.0             996.0       762.0
# 4          1580.0       1532.5             587.0       762.0
# ...           ...          ...               ...         ...
# 1995        924.0       1164.5             159.0       762.0
# 1996       1209.5        375.0             471.5       762.0
# 1997       1459.5       1715.5            1638.0       762.0
# 1998        184.5        375.0             159.0       762.0
# 1999         62.5       1164.5            1951.0       762.0
#
#       rank_by_touchscreen  rank_by_wifi
# 0                  1503.5         507.5
# 1                   503.5        1507.5
# 2                   503.5        1507.5
# 3                  1503.5        1507.5
# 4                   503.5        1507.5
# ...                   ...           ...
# 1995                503.5        1507.5
# 1996                503.5         507.5
# 1997                503.5        1507.5
# 1998                503.5         507.5
# 1999                503.5         507.5
#
# [2000 rows x 26 columns]

# %% [markdown]
# Data Splitting and Data Scaling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

data=data.iloc[:,:21]

X=data.iloc[:,:-1]
y=data.iloc[:,-1]

sc = StandardScaler()
X=sc.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

lg = LogisticRegression()
lg.fit(X_train, y_train)
y_pred_lg = lg.predict(X_test)
#print(y_pred_lg)
print("Trainig Score of Logistic Regression is {}".format(lg.score(X_train, y_train)*100))
as_lg = accuracy_score(y_test, y_pred_lg)*100
print("Accuracy of Logistic Regression classifier is {}".format(as_lg))
print("Confusion matrix of Logistic Regression classifier : \n{}".format(confusion_matrix(y_test, y_pred_lg)))
print("\n")
print("{}".format(classification_report(y_test, y_pred_lg)))
# Out:
# Trainig Score of Logistic Regression is 97.93333333333332
# Accuracy of Logistic Regression classifier is 96.2
# Confusion matrix of Logistic Regression classifier :
# [[122   2   0   0]
#  [  3 103   4   0]
#  [  0   5 116   4]
#  [  0   0   1 140]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       124
#            1       0.94      0.94      0.94       110
#            2       0.96      0.93      0.94       125
#            3       0.97      0.99      0.98       141
#
#     accuracy                           0.96       500
#    macro avg       0.96      0.96      0.96       500
# weighted avg       0.96      0.96      0.96       500

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
Nb = GaussianNB()
Nb.fit(X_train, y_train)
print("Traning Score of Naive Bayes is {}".format(Nb.score(X_train, y_train)*100))
y_pred_Nb = Nb.predict(X_test)
print(y_pred_Nb)
as_Nb = accuracy_score(y_test, y_pred_Nb)*100
print("Accuracy of Naive Bayes classifier is {}".format(as_Nb))
print("Confusion matrix of Naive Bayes : \n{}".format(confusion_matrix(y_test, y_pred_Nb)))
print("\n")
print("{}".format(classification_report(y_test, y_pred_Nb)))
# Out:
# Traning Score of Naive Bayes is 81.39999999999999
# [3 0 2 1 3 0 0 3 3 1 1 3 0 2 3 0 3 2 2 1 0 0 3 1 1 2 3 1 3 1 1 0 1 0 2 3 0
#  0 3 3 3 1 3 3 1 3 0 2 3 1 1 3 0 2 0 3 2 2 0 3 3 1 3 2 2 2 3 3 2 2 3 2 1 0
#  1 3 2 2 2 1 3 2 3 0 0 0 2 1 1 3 1 2 2 1 0 3 3 3 0 3 1 2 3 1 3 1 2 3 2 3 3
#  0 0 2 3 3 0 1 1 0 1 3 2 2 1 2 1 1 0 2 1 3 3 3 3 3 3 1 0 2 1 2 2 3 0 3 0 0
#  2 0 1 1 1 1 3 1 0 3 1 3 2 1 3 1 2 3 3 2 1 0 3 2 2 3 3 0 1 2 3 0 3 1 1 2 3
#  1 2 0 2 3 1 1 0 2 3 0 1 3 2 0 3 3 3 1 1 3 2 3 0 0 0 2 3 3 0 0 1 3 2 3 3 3
#  0 0 2 2 3 2 1 2 0 0 0 3 2 0 2 2 0 1 0 2 3 3 0 0 1 3 3 2 3 0 3 1 1 0 1 3 2
#  2 0 0 1 3 3 2 2 3 2 1 0 3 3 2 2 3 2 2 2 1 0 2 2 1 0 0 2 2 2 2 0 2 2 0 1 2
#  3 0 2 0 0 1 3 0 0 2 3 1 2 0 1 0 3 0 3 3 2 3 1 1 2 1 1 2 0 1 0 3 1 0 3 1 0
#  1 2 0 3 2 2 0 1 3 0 2 1 1 2 2 2 0 2 0 0 3 1 3 3 1 2 0 3 2 2 1 3 2 3 3 3 0
#  3 0 3 0 1 1 2 2 1 3 1 1 0 1 1 3 0 0 1 3 0 3 0 2 2 1 1 0 2 0 0 1 3 0 3 3 0
#  2 2 3 2 1 3 2 0 2 2 2 0 0 3 0 0 1 1 3 1 3 2 0 3 0 0 1 3 0 1 3 3 2 2 3 0 0
#  1 2 0 2 0 3 3 0 3 3 0 2 1 1 0 2 2 1 3 2 2 0 2 0 3 3 2 1 0 3 1 2 0 0 1 3 0
#  3 0 0 1 2 0 1 2 0 2 1 1 2 0 3 1 1 3 1]
# Accuracy of Naive Bayes classifier is 84.39999999999999
# Confusion matrix of Naive Bayes :
# [[117   7   0   0]
#  [  6  83  21   0]
#  [  0  22  92  11]
#  [  0   0  11 130]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       124
#            1       0.74      0.75      0.75       110
#            2       0.74      0.74      0.74       125
#            3       0.92      0.92      0.92       141
#
#     accuracy                           0.84       500
#    macro avg       0.84      0.84      0.84       500
# weighted avg       0.84      0.84      0.84       500

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
svc = SVC(kernel="rbf")
svc.fit(X_train, y_train)
print("Traning Score of SVM is {}".format(svc.score(X_train, y_train)*100))
y_pred_svm = svc.predict(X_test)
print(y_pred_svm)
am_svm = accuracy_score(y_test, y_pred_svm)*100
print("Accuracy of SVM classifier is {}".format(am_svm))
print("Confusion matrix of SVM classifier : \n{}".format(confusion_matrix(y_test, y_pred_svm)))
print("\n")
print("{}".format(classification_report(y_test, y_pred_svm)))
# Out:
# Traning Score of SVM is 98.06666666666666
# [3 0 2 1 3 0 0 2 3 1 1 3 0 2 3 0 3 2 2 1 0 0 3 1 1 2 3 1 3 1 1 0 1 0 1 3 0
#  0 3 3 3 2 3 3 1 3 0 2 3 1 1 2 0 3 0 2 2 2 0 3 3 1 2 2 1 2 3 2 2 2 3 2 1 0
#  1 3 2 2 2 2 3 3 3 0 0 0 2 1 2 3 1 2 2 0 0 3 3 3 0 3 1 1 2 1 3 2 2 3 2 3 2
#  0 0 1 2 3 0 0 1 0 0 3 2 2 1 1 1 1 0 1 1 3 3 3 3 3 3 2 0 1 1 2 1 3 0 3 0 0
#  1 0 1 1 1 1 3 1 0 3 1 3 2 1 2 1 2 3 3 3 1 0 3 1 2 3 3 0 2 2 3 1 2 1 0 1 2
#  1 2 0 2 3 1 1 1 2 3 0 0 2 2 0 3 3 2 1 2 3 3 3 0 0 0 2 3 3 0 0 1 3 1 3 2 3
#  0 0 2 3 3 1 0 2 0 0 0 3 2 1 2 2 1 1 1 2 3 3 0 0 1 3 3 1 3 0 3 1 1 0 2 3 3
#  2 0 0 1 2 3 2 2 3 2 1 0 3 3 2 1 3 2 2 2 1 0 2 1 2 0 0 2 2 1 2 0 1 3 0 1 2
#  3 0 2 0 1 1 3 0 0 2 3 1 2 0 2 0 3 0 3 3 2 3 1 2 2 1 1 1 0 2 0 3 1 0 3 0 0
#  1 3 0 3 2 1 0 2 3 0 1 1 1 2 1 1 0 2 0 0 3 1 2 3 2 3 0 3 2 2 1 3 2 3 3 3 0
#  2 0 2 0 1 1 2 2 1 2 1 1 0 1 2 3 0 0 1 3 0 3 0 1 2 1 1 0 2 0 0 1 3 0 3 3 0
#  2 1 3 1 2 3 2 0 3 2 2 0 0 3 0 1 1 1 3 2 2 1 0 3 0 0 1 3 0 0 3 2 2 2 3 0 0
#  1 2 1 2 0 3 3 0 3 3 0 2 2 0 0 2 2 1 3 2 2 0 2 0 3 3 2 1 0 3 1 2 0 0 1 3 0
#  3 0 0 1 2 0 1 2 1 2 2 1 2 0 3 0 2 2 2]
# Accuracy of SVM classifier is 89.0
# Confusion matrix of SVM classifier :
# [[118   6   0   0]
#  [  6  96   8   0]
#  [  0  15 106   4]
#  [  0   0  16 125]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       124
#            1       0.82      0.87      0.85       110
#            2       0.82      0.85      0.83       125
#            3       0.97      0.89      0.93       141
#
#     accuracy                           0.89       500
#    macro avg       0.89      0.89      0.89       500
# weighted avg       0.89      0.89      0.89       500

# %% [markdown]
# Desision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
Dt = DecisionTreeClassifier(criterion="entropy")
Dt.fit(X_train, y_train)
print("Traning Score of Decision Tree classifier is {}".format(Dt.score(X_train, y_train)*100))
y_pred_Dt = Dt.predict(X_test)
print(y_pred_Dt)
am_Dt = accuracy_score(y_test, y_pred_Dt)*100
print("Accuracy of Decision Tree classifier is {}".format(am_Dt))
print("Confusion matrix of Dcision Tree classifier : \n{}".format(confusion_matrix(y_test, y_pred_Dt)))
print("\n")
print("{}".format(classification_report(y_test, y_pred_Dt)))
# Out:
# Traning Score of Decision Tree classifier is 100.0
# [3 0 2 2 2 0 0 3 3 1 0 3 0 2 3 0 3 2 2 1 0 0 3 1 1 1 3 1 3 1 1 0 2 1 1 3 0
#  0 3 3 2 1 3 2 1 3 0 1 3 1 1 3 0 3 0 3 2 1 0 3 3 1 3 2 1 2 3 2 2 2 3 2 1 0
#  1 3 2 2 1 2 3 3 3 0 0 1 2 1 2 3 1 3 2 1 0 3 2 3 0 3 2 1 3 1 3 2 2 3 2 3 3
#  0 0 1 2 2 0 0 1 0 0 3 2 2 1 2 1 1 0 2 1 3 2 3 3 3 3 2 0 0 1 2 2 3 0 3 0 0
#  2 0 1 1 2 1 3 1 1 3 2 3 2 1 3 1 2 3 3 2 1 0 3 2 2 3 3 0 2 2 3 0 3 1 0 1 3
#  2 2 0 2 3 1 1 0 2 3 0 1 2 1 0 3 3 3 1 2 3 3 3 1 0 0 2 3 3 0 0 1 3 2 3 3 3
#  0 0 2 3 3 1 0 2 0 0 0 3 3 0 2 2 0 1 0 2 3 3 0 0 1 3 3 1 3 0 3 1 1 0 2 3 3
#  2 0 1 1 2 3 2 2 3 2 1 0 3 2 2 1 3 2 2 2 0 0 2 2 2 0 0 2 2 2 2 0 1 3 0 1 2
#  3 0 2 1 1 1 3 0 0 2 3 0 2 0 2 0 3 0 3 3 2 3 0 2 2 1 1 1 0 1 0 2 1 0 3 1 0
#  0 2 0 3 1 2 0 1 3 0 2 2 1 1 1 2 0 2 0 1 3 1 3 3 2 2 0 3 2 1 1 3 2 3 3 3 0
#  2 0 2 0 1 1 2 3 1 3 1 2 1 1 2 2 0 1 1 3 0 3 0 1 2 1 1 0 3 1 0 1 3 0 3 3 0
#  2 1 3 1 1 3 2 0 2 3 2 0 0 3 0 1 1 1 3 2 3 2 1 2 0 0 1 3 0 0 3 2 1 2 3 0 0
#  1 2 0 2 0 3 3 0 2 3 0 3 2 1 0 2 2 1 3 2 2 0 2 0 3 3 2 1 0 3 0 2 0 0 1 3 0
#  3 0 0 2 2 0 1 2 0 2 1 1 3 0 3 1 1 3 2]
# Accuracy of Decision Tree classifier is 86.0
# Confusion matrix of Dcision Tree classifier :
# [[112  12   0   0]
#  [ 10  90  10   0]
#  [  0  11 103  11]
#  [  0   0  16 125]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       124
#            1       0.80      0.82      0.81       110
#            2       0.80      0.82      0.81       125
#            3       0.92      0.89      0.90       141
#
#     accuracy                           0.86       500
#    macro avg       0.86      0.86      0.86       500
# weighted avg       0.86      0.86      0.86       500

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
Rf = RandomForestClassifier(n_estimators=300)
Rf.fit(X_train, y_train)
print("Traning Score of Random Forest classifier is {}".format(Rf.score(X_train, y_train)*100))
y_pred_Rf = Rf.predict(X_test)
print(y_pred_Rf)
am_Rf = accuracy_score(y_test, y_pred_Rf)*100
print("Accuracy of Decision Tree classifier is {}".format(am_Rf))
print("Confusion matrix of Dcision Tree classifier : \n{}".format(confusion_matrix(y_test, y_pred_Rf)))
print("\n")
print("{}".format(classification_report(y_test, y_pred_Rf)))
# Out:
# Traning Score of Random Forest classifier is 100.0
# [3 0 2 1 3 0 0 3 3 1 0 3 0 2 3 0 3 2 2 1 0 0 3 1 1 2 3 1 3 1 1 0 1 0 2 3 0
#  0 3 3 3 1 3 3 1 3 0 1 3 1 1 3 0 3 0 3 2 1 0 3 3 1 3 2 1 2 3 3 1 2 3 2 1 0
#  1 3 2 2 2 1 3 3 3 0 0 0 2 0 2 3 1 2 2 1 0 2 3 3 0 3 1 2 3 1 3 2 2 3 2 3 3
#  0 0 2 3 3 0 1 1 0 1 3 2 2 1 2 1 1 0 2 1 3 3 3 3 3 3 1 0 1 1 2 2 3 0 3 0 0
#  2 0 1 1 1 1 3 0 0 3 1 3 2 1 3 1 2 3 3 2 1 0 3 2 2 3 3 0 1 2 3 0 2 1 0 1 3
#  1 2 0 2 3 1 1 0 2 3 0 1 3 2 0 3 3 3 1 1 3 3 3 0 0 0 2 3 3 0 0 1 3 2 3 3 3
#  0 0 2 2 3 1 0 2 0 0 0 3 2 0 2 2 0 1 0 2 3 3 0 0 1 3 3 1 3 0 3 1 1 0 1 3 2
#  2 0 0 1 2 3 2 2 3 2 1 0 3 3 2 1 3 2 2 2 1 0 2 1 1 0 0 2 2 2 2 0 1 3 0 1 2
#  3 0 2 0 1 1 3 0 0 2 3 1 1 0 2 0 3 0 3 3 2 3 1 1 2 1 1 2 0 1 0 3 1 0 3 1 0
#  1 2 0 3 2 2 0 1 3 0 2 1 1 2 2 2 0 2 0 0 3 1 2 3 2 2 0 3 2 2 1 3 2 3 3 3 0
#  2 0 3 0 1 1 2 3 1 3 1 1 0 1 2 3 0 0 1 3 0 3 0 1 2 1 1 0 3 1 0 1 3 0 3 3 0
#  2 1 3 2 1 3 2 0 2 3 2 0 0 3 0 1 1 1 3 2 3 2 0 3 0 0 1 3 0 0 3 3 2 2 3 0 0
#  1 2 0 2 0 3 3 0 2 3 0 2 2 1 0 2 2 1 3 2 2 0 2 0 3 3 2 1 0 3 0 2 0 0 1 3 0
#  3 0 0 1 2 0 1 2 0 2 1 1 2 0 3 1 1 3 2]
# Accuracy of Decision Tree classifier is 87.8
# Confusion matrix of Dcision Tree classifier :
# [[121   3   0   0]
#  [  6  91  13   0]
#  [  0  20  95  10]
#  [  0   0   9 132]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       124
#            1       0.80      0.83      0.81       110
#            2       0.81      0.76      0.79       125
#            3       0.93      0.94      0.93       141
#
#     accuracy                           0.88       500
#    macro avg       0.87      0.87      0.87       500
# weighted avg       0.88      0.88      0.88       500

# %% [markdown]
# Comparing Accuracies of all the models using Bar Chart

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

classifiers = ["Logistic Regression", "Naive Bayes", "SVM", "Decision Tree", "Random Forest"]
Acc_list = [as_lg, as_Nb, am_svm, am_Dt, am_Rf]
df_models = pd.DataFrame({"Model":classifiers, "Accuracy":Acc_list})
px.histogram(data_frame=df_models, x="Model", y="Accuracy", color=["red","yellow","blue","orange","green"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c476f018-fbfa-442f-8175-6e33c9f55e96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c476f018-fbfa-442f-8175-6e33c9f55e96")) {                    Plotly.newPlot(                        "c476f018-fbfa-442f-8175-6e33c9f55e96",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=red<br>Model=%{x}<br>sum of Accuracy=%{y}<extra></extra>","legendgroup":"red","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"red","offsetgroup":"red","orientation":"v","showlegend":true,"x":["Logistic Regression"],"xaxis":"x","y":[96.2],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=yellow<br>Model=%{x}<br>sum of Accuracy=%{y}<extra></extra>","legendgroup":"yellow","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"yellow","offsetgroup":"yellow","orientation":"v","showlegend":true,"x":["Naive Bayes"],"xaxis":"x","y":[84.39999999999999],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=blue<br>Model=%{x}<br>sum of Accuracy=%{y}<extra></extra>","legendgroup":"blue","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"blue","offsetgroup":"blue","orientation":"v","showlegend":true,"x":["SVM"],"xaxis":"x","y":[89.0],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=orange<br>Model=%{x}<br>sum of Accuracy=%{y}<extra></extra>","legendgroup":"orange","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"orange","offsetgroup":"orange","orientation":"v","showlegend":true,"x":["Decision Tree"],"xaxis":"x","y":[86.0],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=green<br>Model=%{x}<br>sum of Accuracy=%{y}<extra></extra>","legendgroup":"green","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"green","offsetgroup":"green","orientation":"v","showlegend":true,"x":["Random Forest"],"xaxis":"x","y":[87.8],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"co ...

# %% [markdown]
# Performing K-Fold and Cross Validation on all the algorithms to get better accuracy and result

# %%
K_Fold = KFold(n_splits=10)
abc=[]
Acc = []
Classifiers = ["Logistic Regression", "Naive Bayes", "SVM", "Decision Tree", "Random Forest"]
Models = [LogisticRegression(), GaussianNB(), SVC(kernel="rbf"), DecisionTreeClassifier(criterion="entropy"), RandomForestClassifier(n_estimators=300)]
for i in Models:
    model = i
    CV_Result = cross_val_score(model, X_train, y_train, cv=K_Fold, scoring="accuracy")
    abc.append(CV_Result.mean())
    Acc.append(CV_Result)

CV_ModelData = pd.DataFrame(abc, index=Classifiers)
CV_ModelData.columns = ["CV Mean"]
CV_ModelData
# Out:
#                       CV Mean
# Logistic Regression  0.960000
# Naive Bayes          0.801333
# SVM                  0.873333
# Decision Tree        0.845333
# Random Forest        0.872000

# %% [markdown]
# Plotting Box Plot Accuracies we got from Cross Validation and K-fold

# %%
box = pd.DataFrame(Acc, index=[Classifiers])
boxT = box.T
plt.figure(figsize=(10,8))
ax = sns.boxplot(data=boxT, orient="v", palette="Set2", width=.6)
